# %% [markdown]
# # Dictonary

# %% [raw]
# Inside the dic we have something called as {key : value}
# like example : Student={"name ": "jay ","Age":23 "" class: "z"}

# %%
student= {"name": " jay kumar singh",
         "Age" : 21,
         "city": "Bangalore"}
print(student)
# Out:
# {'name': ' jay kumar singh', 'Age': 21, 'city': 'Bangalore'}

# %%
emp = {"emp name" : "jay",
       "emp id": 12345,
       "emp salary": 50000,
       "emp dep": "cse"}
print(emp)
# Out:
# {'emp name': 'jay', 'emp id': 12345, 'emp salary': 50000, 'emp dep': 'cse'}

# %% [raw]
# key value pair
# ordered
# mutable
# keys must be unique
# values can be duplicate

# %%
a= {"name":"jay", "Age": 21,"name":"sonal"}
print(a)
# Out:
# {'name': 'sonal', 'Age': 21}

# %% [markdown]
# # multiple name

# %%
empy = {"name": ["aa","bb","cc","dd"],
        "Age" : [23,24,25,26,],
        "Class" :["z","A","B","c"]

       }
print(empy)
# Out:
# {'name': ['aa', 'bb', 'cc', 'dd'], 'Age': [23, 24, 25, 26], 'Class': ['z', 'A', 'B', 'c']}

# %%
employee = { "emp name" : ["A","B","C","D"],
             "emp id" :[1,2,3,4],
             "emp salary": [12,23,54,5],
             "emp dep" :["cse","S","a","Q"]
           }
print(employee)
# Out:
# {'emp name': ['A', 'B', 'C', 'D'], 'emp id': [1, 2, 3, 4], 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q']}

# %% [markdown]
# # how acess the dic

# %%
print(employee["emp name"])
# Out:
# ['A', 'B', 'C', 'D']

# %%
print(employee["emp id"])
# Out:
# [1, 2, 3, 4]

# %%
print(employee["emp salary"])
# Out:
# [12, 23, 54, 5]

# %%
print(employee["emp dep"])
# Out:
# ['cse', 'S', 'a', 'Q']

# %% [markdown]
# # Add new element

# %%
employee[" emp marks"]=69
print(employee)
# Out:
# {'emp name': ['A', 'B', 'C', 'D'], 'emp id': [1, 2, 3, 4], 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69}

# %%
employee["emp city"]= "delhi"
print(employee)
# Out:
# {'emp name': ['A', 'B', 'C', 'D'], 'emp id': [1, 2, 3, 4], 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'emp city': 'delhi'}

# %%
employee["grade"]="A+"
print(employee)
# Out:
# {'emp name': ['A', 'B', 'C', 'D'], 'emp id': [1, 2, 3, 4], 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'emp city': 'delhi', 'grade': 'A+'}

# %%
employee["emp cgpa"]=9.25
print(employee)
# Out:
# {'emp name': ['A', 'B', 'C', 'D'], 'emp id': [1, 2, 3, 4], 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'emp city': 'delhi', 'grade': 'A+', 'emp cgpa': 9.25}

# %% [markdown]
# # UPdate|

# %%
employee["emp name"]= "RAvi"
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi'}

# %%
employee["emp cgpa"]= "9.50"
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi', 'emp cgpa': '9.50'}

# %%
employee["emp name"]= "RAvi"
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi', 'emp cgpa': '9.50'}

# %% [markdown]
# # Update Multiple Value together

# %%
employee.update({
    "emp id": 21,
    "emp city" : "Mysore" })
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi', 'emp cgpa': '9.50', 'emp city': 'Mysore'}

# %% [markdown]
# # Delete

# %%
del employee["emp cgpa"]

# %%
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi', 'emp city': 'Mysore'}

# %%
del employee["emp city"]
print(employee)
# Out:
# {'emp name': 'RAvi', 'emp id': 21, 'emp salary': [12, 23, 54, 5], 'emp dep': ['cse', 'S', 'a', 'Q'], ' emp marks': 69, 'grade': 'A+', ('emp name', 0): 'RAvi'}

# %% [markdown]
# # Removing only column

# %%
employee.clear()
print(employee)
# Out:
# {}

# %%
orders ={"order id ":[1,2,3,4,5],
         "order name": ["a","b","c","D","E"],
         "product" :["z","x","c","v","B"],
         "payment_mode" : ["Q","W","E","R","z","t"]}
print(orders)
# Out:
# {'order id ': [1, 2, 3, 4, 5], 'order name': ['a', 'b', 'c', 'D', 'E'], 'product': ['z', 'x', 'c', 'v', 'B'], 'payment_mode': ['Q', 'W', 'E', 'R', 'z', 't']}

# %%
print(len(orders))
# Out:
# 4

# %%
print(orders.keys)
# Out:
# <built-in method keys of dict object at 0x0000025963DBB680>

# %%
print(orders.values())
# Out:
# dict_values([[1, 2, 3, 4, 5], ['a', 'b', 'c', 'D', 'E'], ['z', 'x', 'c', 'v', 'B'], ['Q', 'W', 'E', 'R', 'z', 't']])

# %% [markdown]
# # Function

# %% [raw]
# A function is a resuable block of code that perform a specific task .

# %%
a=input("Enter the name : ")
# Out:
# Enter the name :  Jay Kumar SIngh

# %%
a=input("Enter the name : ")
# Out:
# Enter the name :  Sonal

# %%
print(a)
# Out:
# Sonal

# %% [raw]
# # Function we have 2 type
# 1.user define
# 2. predefined

# %% [markdown]
# # Syntax of function

# %%
# def function name ():

#calling the function
funcation name()

# %%
def jay():
    print("welcome jay ")

jay()
jay()
jay()
jay()
jay()
# Out:
# welcome jay
# welcome jay
# welcome jay
# welcome jay
# welcome jay

# %%
def sonal():
    print("welcome jay for today class ")

sonal()
sonal()
sonal()
sonal()
sonal()
# Out:
# welcome jay for today class
# welcome jay for today class
# welcome jay for today class
# welcome jay for today class
# welcome jay for today class

# %%
def greet(name):
    print("welcome",name)
greet("jay")
greet("kavaya")
greet("sangeeta")
# Out:
# welcome jay
# welcome kavaya
# welcome sangeeta
