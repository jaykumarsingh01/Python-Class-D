# %%
password=""
while password != "python123":
    password =input("enter your password")
print("access granted")
# Out:
# enter your password fdt
# enter your password \f
# enter your password ffdt
# enter your password trd]hgfd\
# enter your password hgfdswertyuio;lkbvc
# enter your password hgfdwertyu
# enter your password hgdswerty
# enter your password python123
# access granted

# %%
# break immediatly exits the loop

# %%
while True:
    name = input("enter your name (or 'quit')")
        print("hello",name)
        print("loop ended")
     if name == 'quit':
        break
# Out:
# enter your name (or 'quit') hgfd
# enter your name (or 'quit') quit
# hello quit
# loop ended

# %%
password=""
while password != "python123":
    password =input("enter your password")
    while password <=4:
        print("timesup")
print("access granted")
# Out:
# enter your password 11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 while password != "python123":
#       3     password =input("enter your password")
# ----> 4     while password<=4:
#       5         print("timesup")
#       6 print("access granted")
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
num = 0

while num <5:
    num+=1
    if num ==3:
        continue
    print(num)
# Out:
# 1
# 2
# 4
# 5

# %%
num=20
while num<30:
    num=+1
    if num==25:
        continue
