# %%
num=20
while num<30:
    num+=1
    if num==25:
        continue
    print(num)
# Out:
# 21
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 30

# %%
password=""
attempt=0
while password != "python123" and attempt <4:
    attempt +=1
    password =input("enter your password")
    if password == "python123":
        print("access granted")
    elif password !="python123":
        print("Wrong password")
else:
        print("time's up")
# Out:
# enter your password tftftg
# Wrong password
# enter your password gtftyfv
# Wrong password
# enter your password ytftyg
# Wrong password
# enter your password gfty
# Wrong password
# time's up

# %%
print('jay')
