# %%
 # my first program

# %%
print("jay kumar singh ,this is my first program ")
# Out:
# jay kumar singh ,this is my first program

# %%
# how to create a variable
a=5
b=10
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 5
# 10
# <class 'int'>
# <class 'int'>

# %%
# how to create a float value
new_variable=6.5987
c=10.11
print(new_variable)
print(type(new_variable))
# Out:
# 6.5987
# <class 'float'>

# %%
# how to store a value string
z="jay kumar singh"
print(z)
print(type(z))
# Out:
# jay kumar singh
# <class 'str'>

# %%
# how to create tuple
z1=(3,4,5,6,7,8,9)
print(z1)
print(type(z1))
# Out:
# (3, 4, 5, 6, 7, 8, 9)
# <class 'tuple'>

# %%
# how to create a list
z2=[1,2,3,4,5,6,7,8,9]
print(z2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# how to check the datatypes
print(type(z2))
# Out:
# <class 'list'>

# %%
# how to create a set
colour={"red","blue","orange"}
print(colour)
print(type(colour))
# Out:
# {'blue', 'red', 'orange'}
# <class 'set'>

# %%
# how to create dictaniory
student={"name","Age","branch"}
print(student)
print(type(student))
# Out:
# {'branch', 'Age', 'name'}
# <class 'set'>

# %%
# how to create a boolen
is_pass=True
print(is_pass)
print(type(is_pass))
# Out:
# True
# <class 'bool'>

# %%
name="jay kumar singh"
age=21
classes="python"
print(name,age,classes)
# Out:
# jay kumar singh 21 python

# %%
# create multiple variable
a=5
b=10
c="jay"

x,y,z=5,10,"jay"
print(x,y,z)
# Out:
# 5 10 jay

# %%
a=b=c=100
print(a)
print(b)
print(c)
# Out:
# 100
# 100
# 100

# %%
num=input("Enter your name :")
# Out:
# Enter your name : Jay Kumar Singh

# %%
# how to take numbers from the user
age= int(input("Enter your age :"))
# Out:
# Enter your age : 21

# %%
cgpa= float(input("Enter your cgpa :"))
# Out:
# Enter your cgpa : 9.25

# %%
# arthmetic operation
a=20
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 25
# 15
# 100
# 4.0
# 4
# 0
# 3200000

# %%
num1=int(input("enter the first value : "))
num2=int(input("enter the second value : "))
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
print(num1**num2)
# Out:
# enter the first value :  22
# enter the second value :  2
# 24
# 20
# 44
# 11.0
# 11
# 0
# 484
