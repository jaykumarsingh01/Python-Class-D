# %% [markdown]
# <!-- Q:check the greatest  of 4 no.
# Q:check weather 3 is divided by 5
# Q:check if number is multiple of 10
# Q: check smallest of 3 no.
# Q:check the password is correct or not.
# Q: using the for loop print 5 table and 3 table. -->

# %% [raw]
# Q:check the greatest  of 4 no.
# Q:check weather 3 is divided by 5
# Q:check if number is multiple of 10
# Q: check smallest of 3 no.
# Q:check the password is correct or not.
# Q: using the for loop print 5 table and 3 table.

# %%
# Q1>
def jay(a,b,c,d):
    print(max(10,20,30,50))

jay(10,20,30,40)
# Out:
# 50

# %%
# Q2>
y=3
if y/5==0:
    print("this will be divisible")

else:
    print("this is not divisible")
# Out:
# this is not divisible

# %%
# Q3>
n=int(input("Enter the no."))

if n/10:
    print(" divisible by 10")

else:
    print("Not divisible by 10")
# Out:
# Enter the no. 2987640
#  divisible by 10

# %%
# Q4>
def jay(a,b,c,d):
    print(min(10,20,30,50))

jay(10,20,30,40)
# Out:
# 10

# %%
# Q5>
p =123456789

user= int(input("Enter your password"))

if p==user:
  print("pasword is correct : ")

else:
    print("password is incorrect")
# Out:
# Enter your password 132
# password is incorrect

# %%
p =123456789

user= int(input("Enter your password"))

if p==user:
  print("pasword is correct")

else:
    print("password is incorrect")
# Out:
# Enter your password 123456789
# pasword is correct

# %%
# Q6>
for i in range(1,11):
    print(i*3 ,i*5)
# Out:
# 3 5
# 6 10
# 9 15
# 12 20
# 15 25
# 18 30
# 21 35
# 24 40
# 27 45
# 30 50
