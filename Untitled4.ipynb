# %%
name ="python"

i=0
while i<len(name):
    print(name[i])
    i+=1
# Out:
# p
# y
# t
# h
# o
# n

# %%
number=[12,45,23,56,77,23]
largest=number[0]
i=1
while i<len(number):
    if number[i]>largest:
        largest = number[i]
    i+=1
print("the largest number is ",largest)
# Out:
# the largest number is  77

# %%
number=[12,45,23,56,77,23]
largest=number[0]
i=1
while i<len(number):
    if number[i]<largest:
        largest = number[i]
    i+=1
print("the smallest number is ",largest)
# Out:
# the largest number is  12
